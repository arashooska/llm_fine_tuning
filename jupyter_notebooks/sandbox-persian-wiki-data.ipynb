# %%
JSON_PATH = "/raid/aransari/datasets/Persian-Wikipedia-Corpus/Json Format of Persian Wikipedia Pages/jsons/fawiki-20181001-pages-articles-multistream 1 - 100000.json"

# %%
import pandas as pd

df = pd.read_json(JSON_PATH, lines=True)



print(df.head())
# Out:
#    Id        Title  Type  Rank  Namespace  \
# 0   1   صفحهٔ اصلی     0    38          0
# 1  42    ویکی‌پدیا     6   728          0
# 2  47      سالنامه     0    29          0
# 3  49      اطلاعات     0   211          0
# 4  52  محتوای آزاد     0   129          0
#
#                                         RedirectList  IsDisambiguationPage  \
# 0  [صفحه‌ی اصلی, صفحۀ اصلی, صفحه اصلی, صفحهٔ اصلي...                 False
# 1  [ویکی پدیا, ویکیپدیا, دانشنامهٔ ویکیپدیا, دانش...                 False
# 2                                                 []                 False
# 3                                                 []                 False
# 4  [محتويات آزاد, محتویات آزاد, محتواي آزاد, محتو...                 False
#
#    TargetLinksCount                                            InfoBox  \
# 0                30                 {'Title': '', 'KeysAndValues': []}
# 1               313  {'Title': 'website', 'KeysAndValues': [{'Item1...
# ...

# %%
for col in df.columns:
    print(col)
# Out:
# Id
# Title
# Type
# Rank
# Namespace
# RedirectList
# IsDisambiguationPage
# TargetLinksCount
# InfoBox
# Text
# Links
# Parents

# %%
# Print out the first row of the dataframe with no truncation
pd.set_option('display.max_colwidth', 999)
print(df.iloc[1])
# Out:
# Id                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    
# ...
