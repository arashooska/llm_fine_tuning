# %% [markdown]
# #### Import libraries

# %%
import pandas as pd
import re

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# #### Load the responses

# %% [markdown]
# #### Clean up the responses

# %%
def replace_newline_with_space(text):
    return re.sub(r'\n', ' ', text)

# %%
df = df.map(lambda x: replace_newline_with_space(x) if isinstance(x, str) else x)

# %% [markdown]
# #### Grading Rubrics
# <b>Content Rubric:</b>
# - 1 pt for being on topic (even remotely about the question)
# - 1 pt if the answer is >=50% coherent
# - 1 pt if the answer is fully coherent (no words out of place etc)
# - 1 pt for having a reasonable answer
# - 1 extra point for a thorough, non-trivial answer
#
# <b>Grammar Rubric:</b>
# - 1 pt for all words being real words
# - 1 pt for reasonable amount of English
# - 1 pt for subject verb agreement
# - 1 pt for correct word order
# - 1 pt for proper punctuation

# %%
# Content score breakdown
df['chupa_mistral_relevance_score'] = 0      # Max score = 1
df['chupa_mistral_coherence_score'] = 0      # Max score = 2
df['chupa_mistral_reasonable_answer'] = 0    # Max score = 1
df['chupa_mistral_content_bonus_point'] = 0  # Max score = 1

# Grammar score breakdown
df['chupa_mistral_vocab_score'] = 0          # Max score = 1
df['chupa_mistral_bilingual_score'] = 0      # Max score = 1
df['chupa_mistral_subject_verb_score'] = 0   # Max score = 1
df['chupa_mistral_word_order_score'] = 0     # Max score = 1
df['chupa_mistral_punctuation_score'] = 0    # Max score = 1

# General score
df['chupa_mistral_grammar_score'] = 0        # Max score = 5
df['chupa_mistral_content_score'] = 0        # Max score = 5
    
df.head()
# Out:
#                                                            query  \
# 0  مشخص کنید که کدام ساز زهی یا بادی چوبی است: بیس ترمولو، راکت
# 1                                    معنی کمپوست شدن چیزی چیست؟
# 2               چه رنگی از گربه معمولاً تقریباً همیشه ماده است؟
# 3                                    هند چه زمانی استقلال یافت؟
# 4     آیا یک ماموریت سرنشین دار به مریخ ارزش این هزینه را دارد؟
#
#                                                                                                                                                                                                                                                                                                                     local_mistral_response  \
# ...

# %%
df.at[0, 'chupa_mistral_relevance_score'] = 0
df.at[0, 'chupa_mistral_coherence_score'] = 0    
df.at[0, 'chupa_mistral_reasonable_answer'] = 0         
df.at[0, 'chupa_mistral_content_bonus_point'] = 0 

df.at[0, 'chupa_mistral_vocab_score'] = 0        
df.at[0, 'chupa_mistral_bilingual_score'] = 0   
df.at[0, 'chupa_mistral_subject_verb_score'] = 0
df.at[0, 'chupa_mistral_word_order_score'] = 0
df.at[0, 'chupa_mistral_punctuation_score'] = 0

df.at[0, 'chupa_mistral_content_score'] = 0
df.at[0, 'chupa_mistral_grammar_score'] = 0
# ---------------------------------------------------------------
df.at[1, 'chupa_mistral_relevance_score'] = 0
df.at[1, 'chupa_mistral_coherence_score'] = 0    
df.at[1, 'chupa_mistral_reasonable_answer'] = 0         
df.at[1, 'chupa_mistral_content_bonus_point'] = 0 

df.at[1, 'chupa_mistral_vocab_score'] = 0        
df.at[1, 'chupa_mistral_bilingual_score'] = 0   
df.at[1, 'chupa_mistral_subject_verb_score'] = 0
df.at[1, 'chupa_mistral_word_order_score'] = 0
df.at[1, 'chupa_mistral_punctuation_score'] = 0

df.at[1, 'chupa_mistral_content_score'] = 0
df.at[1, 'chupa_mistral_grammar_score'] = 0
# ---------------------------------------------------------------
df.at[2, 'chupa_mistral_relevance_score'] = 0
df.at[2, 'chupa_mistral_coherence_score'] = 0    
df.at[2, 'chupa_mistral_reasonable_answer'] = 0         
df.at[2, 'chupa_mistral_content_bonus_point'] = 0 

df.at[2, 'chupa_mistral_vocab_score'] = 0        
df.at[2, 'chupa_mistral_bilingual_score'] = 0   
df.at[2, 'chupa_mistral_subject_verb_score'] = 0
df.at[2, 'chupa_mistral_word_order_score'] = 0
df.at[2, 'chupa_mistral_punctuation_score'] = 0

df.at[2, 'chupa_mistral_content_score'] = 0
df.at[2, 'chupa_mistral_grammar_score'] = 0
# ---------------------------------------------------------------
df.at[3, 'chupa_mistral_relevance_score'] = 0
df.at[3, 'chupa_mistral_coherence_score'] = 0    
df.at[3, 'chupa_mistral_reasonable_answer'] = 0         
df.at[3, 'chupa_mistral_content_bonus_point'] = 0 

df.at[3, 'chupa_mistral_vocab_score'] = 0        
df.at[3, 'chupa_mistral_bilingual_score'] = 0   
df.at[3, 'chupa_mistral_subject_verb_score'] = 0
df.at[3, 'chupa_mistral_word_order_score'] = 0
df.at[3, 'chupa_mistral_punctuation_score'] = 0

df.at[3, 'chupa_mistral_content_score'] = 0
df.at[3, 'chupa_mistral_grammar_score'] = 0
# ---------------------------------------------------------------
df.at[4, 'chupa_mistral_relevance_score'] = 0
df.at[4, 'chupa_mistral_coherence_score'] = 0    
df.at[4, 'chupa_mistral_reasonable_answer'] = 0         
df.at[4, 'chupa_mistral_content_bonus_point'] = 0 

df.at[4, 'chupa_mistral_vocab_score'] = 0        
df.at[4, 'chupa_mistral_bilingual_score'] = 0   
df.at[4, 'chupa_mistral_subject_verb_score'] = 0
df.at[4, 'chupa_mistral_word_order_score'] = 0
df.at[4, 'chupa_mistral_punctuation_score'] = 0

df.at[4, 'chupa_mistral_content_score'] = 0
df.at[4, 'chupa_mistral_grammar_score'] = 0
# ---------------------------------------------------------------
df.at[4, 'chupa_mistral_relevance_score'] = 0
df.at[4, 'chupa_mistral_coherence_score'] = 0    
df.at[4, 'chupa_mistral_reasonable_answer'] = 0         
df.at[4, 'chupa_mistral_content_bonus_point'] = 0 

df.at[4, 'chupa_mistral_vocab_score'] = 0        
df.at[4, 'chupa_mistral_bilingual_score'] = 0   
df.at[4, 'chupa_mistral_subject_verb_score'] = 0
df.at[4, 'chupa_mistral_word_order_score'] = 0
df.at[4, 'chupa_mistral_punctuation_score'] = 0

df.at[4, 'chupa_mistral_content_score'] = 0
df.at[4, 'chupa_mistral_grammar_score'] = 0
# ---------------------------------------------------------------
df.at[5, 'chupa_mistral_relevance_score'] = 0
df.at[5, 'chupa_mistral_coherence_score'] = 0    
df.at[5, 'chupa_mistral_reasonable_answer'] = 0         
df.at[5, 'chupa_mistral_content_bonus_point'] = 0 

df.at[5, 'chupa_mistral_vocab_score'] = 0        
df.at[5, 'chupa_mistral_bilingual_score'] = 0   
df.at[5, 'chupa_mistral_subject_verb_score'] = 0
df.at[5, 'chupa_mistral_word_order_score'] = 0
df.at[5, 'chupa_mistral_punctuation_score'] = 0

df.at[5, 'chupa_mistral_content_score'] = 0
df.at[5, 'chupa_mistral_grammar_score'] = 0
# ---------------------------------------------------------------
df.at[6, 'chupa_mistral_relevance_score'] = 0
df.at[6, 'chupa_mistral_coherence_score'] = 0    
df.at[6, 'chupa_mistral_reasonable_answer'] = 0         
df.at[6, 'chupa_mistral_content_bonus_point'] = 0 

df.at[6, 'chupa_mistral_vocab_score'] = 0        
df.at[6, 'chupa_mistral_bilingual_score'] = 0   
df.at[6, 'chupa_mistral_subject_verb_score'] = 0
df.at[6, 'chupa_mistral_word_order_score'] = 0
df.at[6, 'chupa_mistral_punctuation_score'] = 0

df.at[6, 'chupa_mistral_content_score'] = 0
df.at[6, 'chupa_mistral_grammar_score'] = 0
# ---------------------------------------------------------------
df.at[6, 'chupa_mistral_relevance_score'] = 0
df.at[6, 'chupa_mistral_coherence_score'] = 0    
df.at[6, 'chupa_mistral_reasonable_answer'] = 0         
df.at[6, 'chupa_mistral_content_bonus_point'] = 0 

df.at[6, 'chupa_mistral_vocab_score'] = 0        
df.at[6, 'chupa_mistral_bilingual_score'] = 0   
df.at[6, 'chupa_mistral_subject_verb_score'] = 0
df.at[6, 'chupa_mistral_word_order_score'] = 0
df.at[6, 'chupa_mistral_punctuation_score'] = 0

df.at[6, 'chupa_mistral_content_score'] = 0
df.at[6, 'chupa_mistral_grammar_score'] = 0
# ---------------------------------------------------------------
df.at[7, 'chupa_mistral_relevance_score'] = 0
df.at[7, 'chupa_mistral_coherence_score'] = 0    
df.at[7, 'chupa_mistral_reasonable_answer'] = 0         
df.at[7, 'chupa_mistral_content_bonus_point'] = 0 

df.at[7, 'chupa_mistral_vocab_score'] = 0        
df.at[7, 'chupa_mistral_bilingual_score'] = 0   
df.at[7, 'chupa_mistral_subject_verb_score'] = 0
df.at[7, 'chupa_mistral_word_order_score'] = 0
df.at[7, 'chupa_mistral_punctuation_score'] = 0

df.at[7, 'chupa_mistral_content_score'] = 0
df.at[7, 'chupa_mistral_grammar_score'] = 0
# ---------------------------------------------------------------
df.at[8, 'chupa_mistral_relevance_score'] = 0
df.at[8, 'chupa_mistral_coherence_score'] = 0    
df.at[8, 'chupa_mistral_reasonable_answer'] = 0         
df.at[8, 'chupa_mistral_content_bonus_point'] = 0 

df.at[8, 'chupa_mistral_vocab_score'] = 0        
df.at[8, 'chupa_mistral_bilingual_score'] = 0   
df.at[8, 'chupa_mistral_subject_verb_score'] = 0
df.at[8, 'chupa_mistral_word_order_score'] = 0
df.at[8, 'chupa_mistral_punctuation_score'] = 0

df.at[8, 'chupa_mistral_content_score'] = 0
df.at[8, 'chupa_mistral_grammar_score'] = 0
# ---------------------------------------------------------------
df.at[9, 'chupa_mistral_relevance_score'] = 0
df.at[9, 'chupa_mistral_coherence_score'] = 0    
df.at[9, 'chupa_mistral_reasonable_answer'] = 0         
df.at[9, 'chupa_mistral_content_bonus_point'] = 0 

df.at[9, 'chupa_mistral_vocab_score'] = 0        
df.at[9, 'chupa_mistral_bilingual_score'] = 0   
df.at[9, 'chupa_mistral_subject_verb_score'] = 0
df.at[9, 'chupa_mistral_word_order_score'] = 0
df.at[9, 'chupa_mistral_punctuation_score'] = 0

df.at[9, 'chupa_mistral_content_score'] = 0
df.at[9, 'chupa_mistral_grammar_score'] = 0

# %%
df.iloc[:10]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       query  \
# ...

# %%
df.iloc[10:20]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
df.iloc[20:30]
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                           query  \
# 20                                                                                                                                                                                                                                                                                                      خلاصه ای از کتاب «ذهن تحصیل کرده، راهنمای آموزش کلاسیکی که هرگز ندیده اید» نوشته سوزان وایز بائر چیست؟
# ...
